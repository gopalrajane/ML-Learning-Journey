# %%
import pandas as pd
import numpy as np


from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

import seaborn as sns

# %%
df = pd.read_csv('train.csv')[['Age','Pclass','SibSp','Parch','Survived']]

# %%
df.head()
# Out:
#     Age  Pclass  SibSp  Parch  Survived
# 0  22.0       3      1      0         0
# 1  38.0       1      1      0         1
# 2  26.0       3      0      0         1
# 3  35.0       1      1      0         1
# 4  35.0       3      0      0         0

# %%
df.shape
# Out:
# (891, 5)

# %%
df.dropna(inplace=True)

# %%
x = df.drop(columns=['Survived'])
y = df['Survived']

# %%
np.mean(cross_val_score(LogisticRegression(),x,y,scoring='accuracy',cv=20))
# Out:
# np.float64(0.6933333333333332)

# %% [markdown]
# <h2>Applying Feature Construction</h2>

# %%
x['Family_member'] = df['SibSp'] + x['Parch'] + 1

# %%
x.head()
# Out:
#     Age  Pclass  SibSp  Parch  Family_member
# 0  22.0       3      1      0              2
# 1  38.0       1      1      0              2
# 2  26.0       3      0      0              1
# 3  35.0       1      1      0              2
# 4  35.0       3      0      0              1

# %%
# A function for sibsp and parch variable

def myfunc(num):
    if num == 1:
        return 0
    elif num > 1 and num <= 4:
        return 1
    else:
        return 2

# %%
x['Family_member_count'] = x['Family_member'].apply(myfunc)

# %%
x.head()
# Out:
#     Age  Pclass  SibSp  Parch  Family_member  Family_member_count
# 0  22.0       3      1      0              2                    1
# 1  38.0       1      1      0              2                    1
# 2  26.0       3      0      0              1                    0
# 3  35.0       1      1      0              2                    1
# 4  35.0       3      0      0              1                    0

# %%
np.mean(cross_val_score(LogisticRegression(),x,y,scoring='accuracy',cv=20))
# Out:
# np.float64(0.7031746031746031)

# %% [markdown]
# <h2>Feature Splitting</h2>

# %%
df = pd.read_csv('train.csv')

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 25            26         1       3
# 597          598         0       3
# 593          594         0       3
# 368          369         1       3
# 631          632         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 597                                Johnson, Mr. Alfred    male  49.0      0
# 593                                 Bourke, Miss. Mary  female   NaN      0
# 368                                Jermyn, Miss. Annie  female   NaN      0
# 631                        Lundahl, Mr. Johan Svensson    male  51.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 25       5  347077  31.3875   NaN        S
# 597      0    LINE   0.0000   NaN        S
# 593      2  364848   7.7500   NaN        Q
# 368      0   14313   7.7500   NaN        Q
# 631      0  347743   7.0542   NaN        S

# %%
df['Name'].head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: str

# %%
df['Title'] = df['Name'].str.split(',',expand=True)[1].str.split('.',expand=True)[0]

# %%
df['Title']
# Out:
# 0         Mr
# 1        Mrs
# 2       Miss
# 3        Mrs
# 4         Mr
#        ...
# 886      Rev
# 887     Miss
# 888     Miss
# 889       Mr
# 890       Mr
# Name: Title, Length: 891, dtype: str

# %%
df[['Title','Name']]
# Out:
#      Title                                               Name
# 0       Mr                            Braund, Mr. Owen Harris
# 1      Mrs  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2     Miss                             Heikkinen, Miss. Laina
# 3      Mrs       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       Mr                           Allen, Mr. William Henry
# ..     ...                                                ...
# 886    Rev                              Montvila, Rev. Juozas
# 887   Miss                       Graham, Miss. Margaret Edith
# 888   Miss           Johnston, Miss. Catherine Helen "Carrie"
# 889     Mr                              Behr, Mr. Karl Howell
# 890     Mr                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Title
# 1       0  PC 17599  71.2833   C85        C    Mrs
# 3       0    113803  53.1000  C123        S    Mrs
# 6       0     17463  51.8625   E46        S     Mr
# 10      1   PP 9549  16.7000    G6        S   Miss
# 11      0    113783  26.5500  C103        S   Miss

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# Title          0
# dtype: int64

# %%
df['Is_married'] = 0
df['Is_married'].loc[df['Title'] == 'Mrs'] = 1
# Out:
# C:\Users\LENOVO THINKBOOK\AppData\Local\Temp\ipykernel_17232\481613268.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   df['Is_married'].loc[df['Title'] == 'Mrs'] = 1

# %%
df['Is_married']
# Out:
# 1      0
# 3      0
# 6      0
# 10     0
# 11     0
#       ..
# 871    0
# 872    0
# 879    0
# 887    0
# 889    0
# Name: Is_married, Length: 183, dtype: int64

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Title  Is_marreid  Is_married
# 1       0  PC 17599  71.2833   C85        C    Mrs           0           0
# 3       0    113803  53.1000  C123        S    Mrs           0           0
# 6       0     17463  51.8625   E46        S     Mr           0           0
# 10      1   PP 9549  16.7000    G6        S   Miss           0           0
# 11      0    113783  26.5500  C103        S   Miss           0           0
