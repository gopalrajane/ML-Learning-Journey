# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.shape
# Out:
# (200, 2)

# %%
df.describe()
# Out:
#              cgpa     package
# count  200.000000  200.000000
# mean     6.990500    2.996050
# std      1.069409    0.691644
# min      4.260000    1.370000
# 25%      6.190000    2.487500
# 50%      6.965000    2.995000
# 75%      7.737500    3.492500
# max      9.580000    4.620000

# %%
#  Scatter Plot

plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel("Package")
# Out:
# Text(0, 0.5, 'Package')

# %%
# Train test split

x = df.drop(columns=['package'])
y = df['package']

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
# Import Linear Regression

from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(x_train,lr.predict(x_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package')
# Out:
# Text(0, 0.5, 'Package')

# %%
# Import -> Mean absolute error, mearn squared error , r2 score

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
y_pred = lr.predict(x_test)

print('Mean Absolute Errror :',mean_absolute_error(y_test,y_pred))
print('Mean Squared Error :',mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Mean Absolute Errror : 0.2884710931878175
# Mean Squared Error : 0.12129235313495527
# RMSE 0.34827051717731616

# %%
print(r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# 0.780730147510384

# %%
x_test.shape
# Out:
# (40, 1)

# %%
1 - ((1-r2)*(40-1)/(40-1-1))
# Out:
# 0.7749598882343415

# %% [markdown]
# <h3>Adding a New Random number column in dataset</h3>

# %%
# Adding a random number column
new_df1 = df.copy()
new_df1['random_feature'] = np.random.random(200)

new_df1 = new_df1[['cgpa','random_feature','package']]
new_df1.head()
# Out:
#    cgpa  random_feature  package
# 0  6.89        0.120056     3.26
# 1  5.12        0.220552     1.98
# 2  7.82        0.851914     3.25
# 3  7.42        0.695013     3.67
# 4  6.94        0.722726     3.57

# %%
# Scatter plot

plt.scatter(new_df1['random_feature'],new_df1['package'])
plt.xlabel('Random Feature')
plt.ylabel('Package')
# Out:
# Text(0, 0.5, 'Package')

# %%
# Again train test split

x = df.drop(columns=['package'])  # df.iloc[:,0:2]
y = df['package']                 # df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)

y_pred = lr.predict(x_test)

# %%
print(r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# 0.780730147510384

# %% [markdown]
# <h3>Adding a New iq column in dataset</h3>

# %%
new_df2 = df.copy()

new_df2['iq'] = new_df2['package'] + (np.random.randint(-12,12,200)/10)

new_df2 = new_df2[['cgpa','iq','package']]

# %%
new_df2.head()
# Out:
#    cgpa    iq  package
# 0  6.89  3.16     3.26
# 1  5.12  1.28     1.98
# 2  7.82  3.95     3.25
# 3  7.42  4.17     3.67
# 4  6.94  3.27     3.57

# %%
plt.scatter(new_df2['iq'],new_df2['package'])
plt.xlabel('IQ')
plt.ylabel('Package')
# Out:
# Text(0, 0.5, 'Package')

# %%
# Train Test Split

x = new_df2.drop(columns=['package'])
y = new_df2['package']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
lr = LinearRegression()

lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8389682489518677

# %%
1 - ((1-r2)*(40-1)/(40-1-2))
# Out:
# 0.7688777230514858
