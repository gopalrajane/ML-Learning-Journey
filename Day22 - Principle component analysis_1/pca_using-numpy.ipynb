# %%
import numpy as np
import pandas as pd

np.random.seed(23)

mu_vec1 = np.array([0,0,0])
cov_mat1 = np.array([[1,0,0],[0,1,0],[0,0,1]])
class1_sample = np.random.multivariate_normal(mu_vec1, cov_mat1, 20)

df = pd.DataFrame(class1_sample, columns=['feature1','feature2','feature3'])
df['target'] = 1

mu_vec2 = np.array([1,1,1])
cov_mat2 = np.array([[1,0,0],[0,1,0],[0,0,1]])
class2_sample = np.random.multivariate_normal(mu_vec2, cov_mat2, 20)

df1 = pd.DataFrame(class2_sample, columns=['feature1','feature2','feature3'])
df1['target'] = 0

df = pd.concat([df, df1], ignore_index=True)

df = df.sample(40)

print(df.head())

df = df.sample(40)
# Out:
#     feature1  feature2  feature3  target
# 2  -0.367548 -1.137460 -1.322148       1
# 34  0.177061 -0.598109  1.226512       0
# 14  0.420623  0.411620 -0.071324       1
# 11  1.968435 -0.547788 -0.679418       1
# 12 -2.506230  0.146960  0.606195       1

# %%
df.head()
# Out:
#     feature1  feature2  feature3  target
# 25  0.290746  0.866975  0.982643       0
# 38 -0.764314  1.566504  1.548788       0
# 24  0.748855  2.593111  1.170818       0
# 15 -0.045438  1.040886 -0.094035       1
# 13 -0.022539  0.013422  0.935945       1

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\lenovo thinkbook\anaconda3\lib\site-packages (6.3.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\lenovo thinkbook\anaconda3\lib\site-packages (from plotly) (2.7.0)
# Requirement already satisfied: packaging in c:\users\lenovo thinkbook\anaconda3\lib\site-packages (from plotly) (25.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\LENOVO THINKBOOK\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\LENOVO THINKBOOK\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\LENOVO THINKBOOK\anaconda3\Lib\site-packages)

# %%
import plotly.express as px

# %%
pip install nbformat
# Out:
# Requirement already satisfied: nbformat in c:\users\lenovo thinkbook\anaconda3\lib\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\lenovo thinkbook\anaconda3\lib\site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\lenovo thinkbook\anaconda3\lib\site-packages (from nbformat) (4.25.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\lenovo thinkbook\anaconda3\lib\site-packages (from nbformat) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\lenovo thinkbook\anaconda3\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\lenovo thinkbook\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lenovo thinkbook\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lenovo thinkbook\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lenovo thinkbook\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat) (0.28.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\lenovo thinkbook\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.5.0)
# Requirement already satisfied: pywin32>=300 in c:\users\lenovo thinkbook\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (311)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\LENOVO THINKBOOK\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\LENOVO THINKBOOK\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\LENOVO THINKBOOK\anaconda3\Lib\site-packages)

# %%
fig = px.scatter_3d(df, x=df['feature1'], y=df['feature2'], z=df['feature3'],
                    color=df['target'].astype('str'))

fig.update_traces(marker=dict(size=12,
                              line=dict(width=2,color='DarkSlateGrey')),
                              selector=dict(mode='markers'))

fig.show()

# %% [markdown]
# <h3>Step 1 -> Applying standard Scaling</h3>

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()

df.iloc[:,:3] = scalar.fit_transform(df.iloc[:,:3])

# %% [markdown]
# <h3>Step 2 -> Find Covarience Matrix</h3>

# %%
covariance_matrix = np.cov([df.iloc[:,0],df.iloc[:,1],df.iloc[:,2]])
print('Covariance Matrix:\n', covariance_matrix)
# Out:
# Covariance Matrix:
#  [[1.02564103 0.20478114 0.080118  ]
#  [0.20478114 1.02564103 0.19838882]
#  [0.080118   0.19838882 1.02564103]]

# %% [markdown]
# <h3>Step 3 -> Finding EV and EVs</h3>

# %%
eigen_values, eigen_vectors = np.linalg.eig(covariance_matrix)

# %%
eigen_values
# Out:
# array([1.3536065 , 0.94557084, 0.77774573])

# %%
eigen_vectors
# Out:
# array([[-0.53875915, -0.69363291,  0.47813384],
#        [-0.65608325, -0.01057596, -0.75461442],
#        [-0.52848211,  0.72025103,  0.44938304]])
