# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# %%
df = pd.read_csv('titanic_toy.csv')

df.shape
# Out:
# (891, 4)

# %%
df.isnull().sum()
# Out:
# Age         177
# Fare         45
# Family        0
# Survived      0
# dtype: int64

# %% [markdown]
# <h2>train-test-split</h2>

# %%
x = df.drop(columns=['Survived'])
y = df['Survived']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#       Age      Fare  Family
# 331  45.5   28.5000       0
# 733  23.0   13.0000       0
# 382  32.0    7.9250       0
# 704  26.0    7.8542       1
# 813   6.0   31.2750       6
# ..    ...       ...     ...
# 106  21.0    7.6500       0
# 270   NaN   31.0000       0
# 860  41.0       NaN       2
# 435  14.0  120.0000       3
# 102  21.0   77.2875       1
#
# [712 rows x 3 columns]

# %%
y_train
# Out:
# 331    0
# 733    0
# 382    0
# 704    0
# 813    0
#       ..
# 106    1
# 270    0
# 860    0
# 435    1
# 102    0
# Name: Survived, Length: 712, dtype: int64

# %%
x_train['Age_arb'] = df['Age'].fillna(99)
x_train['Age_arb2'] = df['Age'].fillna(-1)

x_train['Fare_arb']  = df['Fare'].fillna(99)
x_train['Fare_arb2'] = df['Fare'].fillna(-1)

# %%
print('Original Age variable variance: ', x_train['Age'].var())
print('Age Variance after 99 wala imputation: ', x_train['Age_arb'].var())
print('Age Variance after -1 wala imputation: ', x_train['Age_arb2'].var())

print('Original Fare variable variance: ', x_train['Fare'].var())
print('Fare Variance after 999 wala imputation: ', x_train['Fare_arb'].var())
print('Fare Variance after -1 wala imputation: ', x_train['Fare_arb2'].var())
# Out:
# Original Age variable variance:  210.2517072477435
# Age Variance after 99 wala imputation:  932.9665366701432
# Age Variance after -1 wala imputation:  315.9955036260055
# Original Fare variable variance:  2761.0314349486343
# Fare Variance after 999 wala imputation:  2833.708690936761
# Fare Variance after -1 wala imputation:  2675.2394049177024

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# Original Age Distribution
x_train['Age'].plot(kind='kde',ax=ax)

# Age variable with arbitary 99
x_train['Age_arb'].plot(kind='kde',ax=ax,color='yellow')

# Age variable with arbitary -1
x_train['Age_arb2'].plot(kind='kde',ax=ax,color='red')

lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# Original Age Distribution
x_train['Fare'].plot(kind='kde',ax=ax)

# Age variable with arbitary 99
x_train['Fare_arb'].plot(kind='kde',ax=ax,color='green')

# Age variable with arbitary -1
x_train['Fare_arb2'].plot(kind='kde',ax=ax,color='red')
# Out:
# <Axes: ylabel='Density'>

# %%
x_train.cov()
# Out:
#                   Age         Fare     Family     Age_arb    Age_arb2  \
# Age        210.251707    75.481375  -6.993325  210.251707  210.251707
# Fare        75.481375  2761.031435  18.599163 -111.965046  135.785804
# Family      -6.993325    18.599163   2.830892   -6.941982   -5.034556
# Age_arb    210.251707  -111.965046  -6.941982  932.966537 -166.460682
# Age_arb2   210.251707   135.785804  -5.034556 -166.460682  315.995504
# Fare_arb    75.273024  2761.031435  17.603852 -116.528480  138.114503
# Fare_arb2   69.137162  2761.031435  17.684447 -101.137070  124.270305
#
#               Fare_arb    Fare_arb2
# Age          75.273024    69.137162
# Fare       2761.031435  2761.031435
# Family       17.603852    17.684447
# Age_arb    -116.528480  -101.137070
# Age_arb2    138.114503   124.270305
# Fare_arb   2833.708691  2514.109946
# Fare_arb2  2514.109946  2675.239405

# %%
x_train.corr()
# Out:
#                 Age      Fare    Family   Age_arb  Age_arb2  Fare_arb  \
# Age        1.000000  0.091482 -0.319651  1.000000  1.000000  0.091016
# Fare       0.091482  1.000000  0.207193 -0.069365  0.145071  1.000000
# Family    -0.319651  0.207193  1.000000 -0.135079 -0.168329  0.196548
# Age_arb    1.000000 -0.069365 -0.135079  1.000000 -0.306576 -0.071667
# Age_arb2   1.000000  0.145071 -0.168329 -0.306576  1.000000  0.145956
# Fare_arb   0.091016  1.000000  0.196548 -0.071667  0.145956  1.000000
# Fare_arb2  0.085422  1.000000  0.203212 -0.064017  0.135159  0.913115
#
#            Fare_arb2
# Age         0.085422
# Fare        1.000000
# Family      0.203212
# Age_arb    -0.064017
# Age_arb2    0.135159
# Fare_arb    0.913115
# Fare_arb2   1.000000

# %% [markdown]
# <h2>Using Sklean</h2>

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
imputer1 = SimpleImputer(strategy='constant',fill_value=99)
imputer2 = SimpleImputer(strategy='constant',fill_value=999)


trf = ColumnTransformer([
    ('trf1',imputer1,['Age']),
    ('trf2',imputer2,['Fare'])

],remainder='passthrough')

trf.fit(x_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('trf1',
#                                  SimpleImputer(fill_value=99,
#                                                strategy='constant'),
#                                  ['Age']),
#                                 ('trf2',
#                                  SimpleImputer(fill_value=999,
#                                                strategy='constant'),
#                                  ['Fare'])])

# %%
trf.named_transformers_['trf1'].statistics_
# Out:
# array([99], dtype=object)

# %%
trf.named_transformers_['trf2'].statistics_
# Out:
# array([999], dtype=object)
