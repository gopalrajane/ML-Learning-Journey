# %%
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.feature_selection import SelectKBest,chi2
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('train.csv')

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 254          255         0       3
# 556          557         1       1
# 531          532         0       3
# 79            80         1       3
# 850          851         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 254           Rosblom, Mrs. Viktor (Helena Wilhelmina)  female  41.0      0
# 556  Duff Gordon, Lady. (Lucille Christiana Sutherl...  female  48.0      1
# 531                                  Toufik, Mr. Nakli    male   NaN      0
# 79                            Dowdell, Miss. Elizabeth  female  30.0      0
# 850            Andersson, Master. Sigvard Harald Elias    male   4.0      4
#
#      Parch  Ticket     Fare Cabin Embarked
# 254      2  370129  20.2125   NaN        S
# 556      0   11755  39.6000   A16        C
# 531      0    2641   7.2292   NaN        C
# 79       0  364516  12.4750   NaN        S
# 850      2  347082  31.2750   NaN        S

# %%
df.drop(columns=['PassengerId','Name','Ticket','Cabin'],inplace=True)

# %%
x = df.drop(columns=['Survived'])
y = df['Survived']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 331       1    male  45.5      0      0   28.5000        S
# 733       2    male  23.0      0      0   13.0000        S
# 382       3    male  32.0      0      0    7.9250        S
# 704       3    male  26.0      1      0    7.8542        S
# 813       3  female   6.0      4      2   31.2750        S
# ..      ...     ...   ...    ...    ...       ...      ...
# 106       3  female  21.0      0      0    7.6500        S
# 270       1    male   NaN      0      0   31.0000        S
# 860       3    male  41.0      2      0   14.1083        S
# 435       1  female  14.0      1      2  120.0000        S
# 102       1    male  21.0      0      1   77.2875        S
#
# [712 rows x 7 columns]

# %%
y_train.sample(5)
# Out:
# 68     1
# 658    0
# 205    0
# 395    0
# 702    0
# Name: Survived, dtype: int64

# %% [markdown]
# simpleImputer

# %%
trf1 = ColumnTransformer([
    ('impute_age',SimpleImputer(),['Age']),
    ('impute_embarked',SimpleImputer(strategy='most_frequent'),['Embarked'])
],remainder='passthrough')

# %% [markdown]
# OneHotEcoder

# %%
trf2 = ColumnTransformer([
    ('ohe_sex_embarked',OneHotEncoder(handle_unknown='ignore'),['Sex',['Embarked']])
],remainder='passthrough')

# %% [markdown]
# Scaler

# %%
trf3 = ColumnTransformer([
    ('scale',MinMaxScaler,slice(0,10))
])

# %% [markdown]
# Feature Selection

# %%
trf4 = SelectKBest(score_func=chi2,k=8)

# %% [markdown]
# Train the Model

# %%
trf5 = DecisionTreeClassifier()

# %% [markdown]
# #  create pipeline

# %%
pipe = Pipeline([
    ('trf1',trf1),
    ('trf2',trf2),
    ('trf3',trf3),
    ('trf4',trf4),
    ('trf5',trf5)
])

# %%
pipe.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 pipe.fit(x_train,y_train)
#
# File c:\Users\LENOVO THINKBOOK\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\LENOVO THINKBOOK\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\pipeline.py:613, in Pipeline.fit(self, X, y, **params)
#     606     raise ValueError(
#     607         "The `transform_input` parameter can only be set if metadata "
#     608         "routing is enabled. You can enable metadata routing using "
#     609         "`sklearn.set_config(enable_metadata_routing=True)`."
#     610     )
#     612 routed_params = self._check_method_params(method="fit", props=params)
# --> 613 Xt = self._fit(X, y, routed_params, raw_params=params)
#     614 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     615     if self._final_estimator != "passthrough":
#
# File c:\Users\LENOVO THINKBOOK\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\pipeline.py:547, in Pipeline._fit(self, X, y, routed_params, raw_params)
#     540 # Fit or load from cache the current transformer
#     541 step_params = self._get_metadata_for_step(
#     542     step_idx=step_idx,
#     543     step_params=routed_params[name],
#     544     all_params=raw_params,
#     545 )
# --> 547 X, fitted_transformer = fit_transform_one_cached(
#     548     cloned_transformer,
#     549     X,
#     550     y,
#     551     weight=None,
#     552     message_clsname="Pipeline",
#     553     message=self._log_message(step_idx),
#     554     params=step_params,
#     555 )
#     556 # Replace the transformer of the step with the fitted
#     557 # transformer. This is necessary when loading the transformer
#     558 # from the cache.
#     559 self.steps[step_idx] = (name, fitted_transformer)
#
# File c:\Users\LENOVO THINKBOOK\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\joblib\memory.py:326, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     325 def __call__(self, *args, **kwargs):
# --> 326     return self.func(*args, **kwargs)
#
# File c:\Users\LENOVO THINKBOOK\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\pipeline.py:1484, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1482 with _print_elapsed_time(message_clsname, message):
#    1483     if hasattr(transformer, "fit_transform"):
# -> 1484         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1485     else:
#    1486         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1487             X, **params.get("transform", {})
#    1488         )
#
# File c:\Users\LENOVO THINKBOOK\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\LENOVO THINKBOOK\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\LENOVO THINKBOOK\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\compose\_column_transformer.py:991, in ColumnTransformer.fit_transform(self, X, y, **params)
#     988 self._validate_transformers()
#     989 n_samples = _num_samples(X)
# --> 991 self._validate_column_callables(X)
#     992 self._validate_remainder(X)
#     994 if _routing_enabled():
#
# File c:\Users\LENOVO THINKBOOK\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\compose\_column_transformer.py:545, in ColumnTransformer._validate_column_callables(self, X)
#     543         columns = columns(X)
#     544     all_columns.append(columns)
# --> 545     transformer_to_input_indices[name] = _get_column_indices(X, columns)
#     547 self._columns = all_columns
#     548 self._transformer_to_input_indices = transformer_to_input_indices
#
# File c:\Users\LENOVO THINKBOOK\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_indexing.py:434, in _get_column_indices(X, key)
#     428 def _get_column_indices(X, key):
#     429     """Get feature column indices for input data X and key.
#     430
#     431     For accepted values of `key`, see the docstring of
#     432     :func:`_safe_indexing`.
#     433     """
# --> 434     key_dtype = _determine_key_type(key)
#     435     if _use_interchange_protocol(X):
#     436         return _get_column_indices_interchange(X.__dataframe__(), key, key_dtype)
#
# File c:\Users\LENOVO THINKBOOK\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_indexing.py:238, in _determine_key_type(key, accept_slice)
#     235 # TODO(1.9) remove UserList when the force_int_remainder_cols param
#     236 # of ColumnTransformer is removed
#     237 if isinstance(key, (list, tuple, UserList)):
# --> 238     unique_key = set(key)
#     239     key_type = {_determine_key_type(elt) for elt in unique_key}
#     240     if not key_type:
#
# TypeError: cannot use 'list' as a set element (unhashable type: 'list')
