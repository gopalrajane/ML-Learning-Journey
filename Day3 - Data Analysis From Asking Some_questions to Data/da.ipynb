# %%
import pandas as pd

df = pd.read_csv('titanic.csv')
# Out:
#      survived  pclass                                   name     sex   age  \
# 587         1       1                 Lesurer, Mr. Gustave J    male  35.0
# 589         1       1  Ryerson, Miss. Susan Parker "Suzette"  female  21.0
# 275         0       2             Collander, Mr. Erik Gustaf    male  28.0
# 584         0       2           Troupiansky, Mr. Moses Aaron    male  23.0
# 291         0       3                        Asim, Mr. Adola    male  35.0
#
#          fare  sibsp  parch
# 587  512.3292      0      0
# 589  262.3750      2      2
# 275   13.0000      0      0
# 584   13.0000      0      0
# 291    7.0500      0      0

# %% [markdown]
# 1. How big is Data ?

# %%
df.shape
# Out:
# (714, 8)

# %% [markdown]
# 2. How does the data look like ?

# %%
df.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age     fare  sibsp  parch
# 0    male  22.0   7.2500      1      0
# 1  female  38.0  71.2833      1      0
# 2  female  26.0   7.9250      0      0
# 3  female  35.0  53.1000      1      0
# 4    male  35.0   8.0500      0      0

# %%
df.sample()
# Out:
#      survived  pclass                           name     sex   age   fare  \
# 580         0       3  Ilmakangas, Miss. Pieta Sofia  female  25.0  7.925
#
#      sibsp  parch
# 580      1      0

# %% [markdown]
# 3. What is Data Types of columns ?

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  714 non-null    int64
#  1   pclass    714 non-null    int64
#  2   name      714 non-null    str
#  3   sex       714 non-null    str
#  4   age       714 non-null    float64
#  5   fare      714 non-null    float64
#  6   sibsp     714 non-null    int64
#  7   parch     714 non-null    int64
# dtypes: float64(2), int64(4), str(2)
# memory usage: 44.8 KB

# %% [markdown]
# 4. Are there any missing values ?

# %%
df.isnull().sum()
# Out:
# survived    0
# pclass      0
# name        0
# sex         0
# age         0
# fare        0
# sibsp       0
# parch       0
# dtype: int64

# %% [markdown]
# 5. How does the data look Mathematically ?

# %%
df.describe()
# Out:
#          survived      pclass         age        fare       sibsp       parch
# count  714.000000  714.000000  714.000000  714.000000  714.000000  714.000000
# mean     0.406162    2.236695   29.699118   34.694514    0.512605    0.431373
# std      0.491460    0.838250   14.526497   52.918930    0.929783    0.853289
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.125000    8.050000    0.000000    0.000000
# 50%      0.000000    2.000000   28.000000   15.741700    0.000000    0.000000
# 75%      1.000000    3.000000   38.000000   33.375000    1.000000    1.000000
# max      1.000000    3.000000   80.000000  512.329200    5.000000    6.000000

# %% [markdown]
# 6. Are there duplicate values ?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 7. How is the correlation between cols ?

# %%
df.corr(numeric_only=True)
# Out:
# survived    1.000000
# pclass     -0.359653
# age        -0.077221
# fare        0.268189
# sibsp      -0.017358
# parch       0.093317
# Name: survived, dtype: float64

# %%
df.corr(numeric_only=True)['survived']
# Out:
# survived    1.000000
# pclass     -0.359653
# age        -0.077221
# fare        0.268189
# sibsp      -0.017358
# parch       0.093317
# Name: survived, dtype: float64
